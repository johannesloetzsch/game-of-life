# %% [markdown]
# ## scipy.opmimize.curve_fit example
# https://www.youtube.com/watch?v=peBOquJ3fDo

# %%
from train.fit import fit_plot
import numpy as np

random_faktor = 1e-1
X = np.array([0, 1, 2, 2.9, 3, 3.1, 4, 5, 6, 7, 8])/8*2-1
Y = [-1, -1, 0, 0.95, 1, 0.95, -1, -1, -1, -1, -1] + random_faktor*np.random.rand(len(X))-random_faktor/2
    
popt, pcov = fit_plot(X, Y)
# Out:
# [-0.31536087  2.77544062  0.13962087]
# cond(pcov) = 487.67726687479933
